# %%
import numpy as np
import sys
sys.path.append('/eagle/fthmc/run')
from Scaling_FT_HMC.utils.func import auto_from_chi
from lametlat.utils.plot_settings import *

n_steps = 10

# %% [markdown]
# ### L32 b3

# %%
hmc_L32_b3_topo = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/scaling/dumps/topo_hmc_L32_beta3.0_nsteps{n_steps}.csv')

fthmc_res2attn_L32_b3_topo_1331 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta3.0_nsteps{n_steps}_res2attn_train_b3.0_L32_1331.csv')
fthmc_res2attn_L32_b3_topo_1984 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta3.0_nsteps{n_steps}_res2attn_train_b3.0_L32_1984.csv')
fthmc_res2attn_L32_b3_topo_1999 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta3.0_nsteps{n_steps}_res2attn_train_b3.0_L32_1999.csv')
fthmc_res2attn_L32_b3_topo_2008 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta3.0_nsteps{n_steps}_res2attn_train_b3.0_L32_2008.csv')
fthmc_res2attn_L32_b3_topo_2017 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta3.0_nsteps{n_steps}_res2attn_train_b3.0_L32_2017.csv')
fthmc_res2attn_L32_b3_topo_2025 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta3.0_nsteps{n_steps}_res2attn_train_b3.0_L32_2025.csv')

max_lag = 64
beta = 3.0
volume = 32**2

hmc_L32_b3_auto = auto_from_chi(hmc_L32_b3_topo, max_lag=max_lag, beta=beta, volume=volume)

fthmc_res2attn_L32_b3_auto_1331 = auto_from_chi(fthmc_res2attn_L32_b3_topo_1331, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b3_auto_1984 = auto_from_chi(fthmc_res2attn_L32_b3_topo_1984, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b3_auto_1999 = auto_from_chi(fthmc_res2attn_L32_b3_topo_1999, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b3_auto_2008 = auto_from_chi(fthmc_res2attn_L32_b3_topo_2008, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b3_auto_2017 = auto_from_chi(fthmc_res2attn_L32_b3_topo_2017, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b3_auto_2025 = auto_from_chi(fthmc_res2attn_L32_b3_topo_2025, max_lag=max_lag, beta=beta, volume=volume)


fig, ax = default_plot()
ax.scatter(np.arange(len(hmc_L32_b3_auto)), hmc_L32_b3_auto, label='HMC, $L=32$, $\\beta=3.0$', marker=marker_ls[0], color=color_ls[0])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b3_auto_1331)), fthmc_res2attn_L32_b3_auto_1331, label='res2attn $L=32$, seed=$1331$', marker=marker_ls[1], color=color_ls[1])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b3_auto_1984)), fthmc_res2attn_L32_b3_auto_1984, label='res2attn $L=32$, seed=$1984$', marker=marker_ls[2], color=color_ls[2])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b3_auto_1999)), fthmc_res2attn_L32_b3_auto_1999, label='res2attn $L=32$, seed=$1999$', marker=marker_ls[3], color=color_ls[3])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b3_auto_2008)), fthmc_res2attn_L32_b3_auto_2008, label='res2attn $L=32$, seed=$2008$', marker=marker_ls[4], color=color_ls[4])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b3_auto_2017)), fthmc_res2attn_L32_b3_auto_2017, label='res2attn $L=32$, seed=$2017$', marker=marker_ls[5], color=color_ls[5])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b3_auto_2025)), fthmc_res2attn_L32_b3_auto_2025, label='res2attn $L=32$, seed=$2025$', marker=marker_ls[6], color=color_ls[6])


ax.set_ylim(-0.1, 1.1)
ax.legend(ncol=2, loc='upper right', fontsize=12)
ax.set_xlabel('MDTU', **fs_p)
ax.set_ylabel('Autocorrelation', **fs_p)
plt.tight_layout()
plt.savefig('plots/res2attn_train_b3_L32_autocorrelation_L32_b3.pdf', transparent=True)
plt.show()

# %%
gamma_hmc = 1 / (1 - hmc_L32_b3_auto[16])

gamma_fthmc_1331 = 1 / (1 - fthmc_res2attn_L32_b3_auto_1331[16])
gamma_fthmc_1984 = 1 / (1 - fthmc_res2attn_L32_b3_auto_1984[16])
gamma_fthmc_1999 = 1 / (1 - fthmc_res2attn_L32_b3_auto_1999[16])
gamma_fthmc_2008 = 1 / (1 - fthmc_res2attn_L32_b3_auto_2008[16])
gamma_fthmc_2017 = 1 / (1 - fthmc_res2attn_L32_b3_auto_2017[16])
gamma_fthmc_2025 = 1 / (1 - fthmc_res2attn_L32_b3_auto_2025[16])

gamma_ratio_1331 = gamma_hmc / gamma_fthmc_1331
gamma_ratio_1984 = gamma_hmc / gamma_fthmc_1984
gamma_ratio_1999 = gamma_hmc / gamma_fthmc_1999
gamma_ratio_2008 = gamma_hmc / gamma_fthmc_2008
gamma_ratio_2017 = gamma_hmc / gamma_fthmc_2017
gamma_ratio_2025 = gamma_hmc / gamma_fthmc_2025

gamma_ratio_L32_b3_mean = np.mean([gamma_ratio_1331, gamma_ratio_1984, gamma_ratio_1999, gamma_ratio_2008, gamma_ratio_2017, gamma_ratio_2025])
gamma_ratio_L32_b3_std = np.std([gamma_ratio_1331, gamma_ratio_1984, gamma_ratio_1999, gamma_ratio_2008, gamma_ratio_2017, gamma_ratio_2025])


print(">>> gamma ratio (16)")
print(f"gamma ratio (16) for L32 b3: {gamma_ratio_1331}, {gamma_ratio_1984}, {gamma_ratio_1999}, {gamma_ratio_2008}, {gamma_ratio_2017}, {gamma_ratio_2025}")
print(f"mean(16) for L32 b3: {gamma_ratio_L32_b3_mean}")
print(f"std(16) for L32 b3: {gamma_ratio_L32_b3_std}")

deltaQ_hmc = [ abs(hmc_L32_b3_topo[i] - hmc_L32_b3_topo[i-1]) for i in range(1, len(hmc_L32_b3_topo))]
deltaQ_fthmc_1331 = [ abs(fthmc_res2attn_L32_b3_topo_1331[i] - fthmc_res2attn_L32_b3_topo_1331[i-1]) for i in range(1, len(fthmc_res2attn_L32_b3_topo_1331))]
deltaQ_fthmc_1984 = [ abs(fthmc_res2attn_L32_b3_topo_1984[i] - fthmc_res2attn_L32_b3_topo_1984[i-1]) for i in range(1, len(fthmc_res2attn_L32_b3_topo_1984))]
deltaQ_fthmc_1999 = [ abs(fthmc_res2attn_L32_b3_topo_1999[i] - fthmc_res2attn_L32_b3_topo_1999[i-1]) for i in range(1, len(fthmc_res2attn_L32_b3_topo_1999))]
deltaQ_fthmc_2008 = [ abs(fthmc_res2attn_L32_b3_topo_2008[i] - fthmc_res2attn_L32_b3_topo_2008[i-1]) for i in range(1, len(fthmc_res2attn_L32_b3_topo_2008))]
deltaQ_fthmc_2017 = [ abs(fthmc_res2attn_L32_b3_topo_2017[i] - fthmc_res2attn_L32_b3_topo_2017[i-1]) for i in range(1, len(fthmc_res2attn_L32_b3_topo_2017))]
deltaQ_fthmc_2025 = [ abs(fthmc_res2attn_L32_b3_topo_2025[i] - fthmc_res2attn_L32_b3_topo_2025[i-1]) for i in range(1, len(fthmc_res2attn_L32_b3_topo_2025))]

deltaQ_hmc_L32_b3_mean = np.mean(deltaQ_hmc)
deltaQ_fthmc_L32_b3_mean = np.mean([np.mean(deltaQ_fthmc_1331), np.mean(deltaQ_fthmc_1984), np.mean(deltaQ_fthmc_1999), np.mean(deltaQ_fthmc_2008), np.mean(deltaQ_fthmc_2017), np.mean(deltaQ_fthmc_2025)])
deltaQ_fthmc_L32_b3_std = np.std([np.mean(deltaQ_fthmc_1331), np.mean(deltaQ_fthmc_1984), np.mean(deltaQ_fthmc_1999), np.mean(deltaQ_fthmc_2008), np.mean(deltaQ_fthmc_2017), np.mean(deltaQ_fthmc_2025)])

print("\n>>> deltaQ")
print(f"deltaQ for HMC L32 b3: {np.mean(deltaQ_hmc)}")
print(f"deltaQ for FTHMC L32 b3: {np.mean(deltaQ_fthmc_1331)}, {np.mean(deltaQ_fthmc_1984)}, {np.mean(deltaQ_fthmc_1999)}, {np.mean(deltaQ_fthmc_2008)}, {np.mean(deltaQ_fthmc_2017)}, {np.mean(deltaQ_fthmc_2025)}")
print(f"mean(deltaQ) ratio for FTHMC L32 b3: {deltaQ_fthmc_L32_b3_mean / deltaQ_hmc_L32_b3_mean}")
print(f"std(deltaQ) ratio for FTHMC L32 b3: {deltaQ_fthmc_L32_b3_std / deltaQ_hmc_L32_b3_mean}")
# Out:
# >>> gamma ratio (16)
# gamma ratio (16) for L32 b3: 1.073588045833882, 1.1451765466540547, 1.121014379961446, 1.2133167303248362, 1.1422430824123853, 1.117386462960524
# mean(16) for L32 b3: 1.1354542080245213
# std(16) for L32 b3: 0.04196339502716587
#
# >>> deltaQ
# deltaQ for HMC L32 b3: 1.6332112332112332
# deltaQ for FTHMC L32 b3: 2.2512820512820513, 2.2285714285714286, 2.168986568986569, 2.254945054945055, 2.2495726495726496, 2.242979242979243
# mean(deltaQ) ratio for FTHMC L32 b3: 1.3670753588516744
# std(deltaQ) ratio for FTHMC L32 b3: 0.018209733669423873

# %% [markdown]
# ### L32 b6

# %%
hmc_L32_b6_topo = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/scaling/dumps/topo_hmc_L32_beta6.0_nsteps{n_steps}.csv')

fthmc_res2attn_L32_b6_topo_1331 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_1331.csv')
fthmc_res2attn_L32_b6_topo_1984 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_1984.csv')
fthmc_res2attn_L32_b6_topo_1999 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_1999.csv')
fthmc_res2attn_L32_b6_topo_2008 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_2008.csv')
fthmc_res2attn_L32_b6_topo_2017 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_2017.csv')
fthmc_res2attn_L32_b6_topo_2025 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L32_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_2025.csv')

max_lag = 64
beta = 6.0
volume = 32**2

hmc_L32_b6_auto = auto_from_chi(hmc_L32_b6_topo, max_lag=max_lag, beta=beta, volume=volume)

fthmc_res2attn_L32_b6_auto_1331 = auto_from_chi(fthmc_res2attn_L32_b6_topo_1331, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b6_auto_1984 = auto_from_chi(fthmc_res2attn_L32_b6_topo_1984, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b6_auto_1999 = auto_from_chi(fthmc_res2attn_L32_b6_topo_1999, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b6_auto_2008 = auto_from_chi(fthmc_res2attn_L32_b6_topo_2008, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b6_auto_2017 = auto_from_chi(fthmc_res2attn_L32_b6_topo_2017, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L32_b6_auto_2025 = auto_from_chi(fthmc_res2attn_L32_b6_topo_2025, max_lag=max_lag, beta=beta, volume=volume)


fig, ax = default_plot()
ax.scatter(np.arange(len(hmc_L32_b6_auto)), hmc_L32_b6_auto, label='HMC, $L=32$, $\\beta=6.0$', marker=marker_ls[0], color=color_ls[0])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b6_auto_1331)), fthmc_res2attn_L32_b6_auto_1331, label='res2attn $L=32$, seed=$1331$', marker=marker_ls[1], color=color_ls[1])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b6_auto_1984)), fthmc_res2attn_L32_b6_auto_1984, label='res2attn $L=32$, seed=$1984$', marker=marker_ls[2], color=color_ls[2])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b6_auto_1999)), fthmc_res2attn_L32_b6_auto_1999, label='res2attn $L=32$, seed=$1999$', marker=marker_ls[3], color=color_ls[3])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b6_auto_2008)), fthmc_res2attn_L32_b6_auto_2008, label='res2attn $L=32$, seed=$2008$', marker=marker_ls[4], color=color_ls[4])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b6_auto_2017)), fthmc_res2attn_L32_b6_auto_2017, label='res2attn $L=32$, seed=$2017$', marker=marker_ls[5], color=color_ls[5])
ax.scatter(np.arange(len(fthmc_res2attn_L32_b6_auto_2025)), fthmc_res2attn_L32_b6_auto_2025, label='res2attn $L=32$, seed=$2025$', marker=marker_ls[6], color=color_ls[6])


ax.set_ylim(0.75, 1.015)
ax.legend(ncol=2, loc='upper right', fontsize=12)
ax.set_xlabel('MDTU', **fs_p)
ax.set_ylabel('Autocorrelation', **fs_p)
plt.tight_layout()
plt.savefig('plots/res2attn_train_b3_L32_autocorrelation_L32_b6.pdf', transparent=True)
plt.show()

# %%
gamma_hmc = 1 / (1 - hmc_L32_b6_auto[16])

gamma_fthmc_1331 = 1 / (1 - fthmc_res2attn_L32_b6_auto_1331[16])
gamma_fthmc_1984 = 1 / (1 - fthmc_res2attn_L32_b6_auto_1984[16])
gamma_fthmc_1999 = 1 / (1 - fthmc_res2attn_L32_b6_auto_1999[16])
gamma_fthmc_2008 = 1 / (1 - fthmc_res2attn_L32_b6_auto_2008[16])
gamma_fthmc_2017 = 1 / (1 - fthmc_res2attn_L32_b6_auto_2017[16])
gamma_fthmc_2025 = 1 / (1 - fthmc_res2attn_L32_b6_auto_2025[16])

gamma_ratio_1331 = gamma_hmc / gamma_fthmc_1331
gamma_ratio_1984 = gamma_hmc / gamma_fthmc_1984
gamma_ratio_1999 = gamma_hmc / gamma_fthmc_1999
gamma_ratio_2008 = gamma_hmc / gamma_fthmc_2008
gamma_ratio_2017 = gamma_hmc / gamma_fthmc_2017
gamma_ratio_2025 = gamma_hmc / gamma_fthmc_2025

gamma_ratio_L32_b6_mean = np.mean([gamma_ratio_1331, gamma_ratio_1984, gamma_ratio_1999, gamma_ratio_2008, gamma_ratio_2017, gamma_ratio_2025])
gamma_ratio_L32_b6_std = np.std([gamma_ratio_1331, gamma_ratio_1984, gamma_ratio_1999, gamma_ratio_2008, gamma_ratio_2017, gamma_ratio_2025])


print(">>> gamma ratio (16)")
print(f"gamma ratio (16) for L32 b6: {gamma_ratio_1331}, {gamma_ratio_1984}, {gamma_ratio_1999}, {gamma_ratio_2008}, {gamma_ratio_2017}, {gamma_ratio_2025}")
print(f"mean(16) for L32 b6: {gamma_ratio_L32_b6_mean}")
print(f"std(16) for L32 b6: {gamma_ratio_L32_b6_std}")

deltaQ_hmc = [ abs(hmc_L32_b6_topo[i] - hmc_L32_b6_topo[i-1]) for i in range(1, len(hmc_L32_b6_topo))]
deltaQ_fthmc_1331 = [ abs(fthmc_res2attn_L32_b6_topo_1331[i] - fthmc_res2attn_L32_b6_topo_1331[i-1]) for i in range(1, len(fthmc_res2attn_L32_b6_topo_1331))]
deltaQ_fthmc_1984 = [ abs(fthmc_res2attn_L32_b6_topo_1984[i] - fthmc_res2attn_L32_b6_topo_1984[i-1]) for i in range(1, len(fthmc_res2attn_L32_b6_topo_1984))]
deltaQ_fthmc_1999 = [ abs(fthmc_res2attn_L32_b6_topo_1999[i] - fthmc_res2attn_L32_b6_topo_1999[i-1]) for i in range(1, len(fthmc_res2attn_L32_b6_topo_1999))]
deltaQ_fthmc_2008 = [ abs(fthmc_res2attn_L32_b6_topo_2008[i] - fthmc_res2attn_L32_b6_topo_2008[i-1]) for i in range(1, len(fthmc_res2attn_L32_b6_topo_2008))]
deltaQ_fthmc_2017 = [ abs(fthmc_res2attn_L32_b6_topo_2017[i] - fthmc_res2attn_L32_b6_topo_2017[i-1]) for i in range(1, len(fthmc_res2attn_L32_b6_topo_2017))]
deltaQ_fthmc_2025 = [ abs(fthmc_res2attn_L32_b6_topo_2025[i] - fthmc_res2attn_L32_b6_topo_2025[i-1]) for i in range(1, len(fthmc_res2attn_L32_b6_topo_2025))]

deltaQ_hmc_L32_b6_mean = np.mean(deltaQ_hmc)
deltaQ_fthmc_L32_b6_mean = np.mean([np.mean(deltaQ_fthmc_1331), np.mean(deltaQ_fthmc_1984), np.mean(deltaQ_fthmc_1999), np.mean(deltaQ_fthmc_2008), np.mean(deltaQ_fthmc_2017), np.mean(deltaQ_fthmc_2025)])
deltaQ_fthmc_L32_b6_std = np.std([np.mean(deltaQ_fthmc_1331), np.mean(deltaQ_fthmc_1984), np.mean(deltaQ_fthmc_1999), np.mean(deltaQ_fthmc_2008), np.mean(deltaQ_fthmc_2017), np.mean(deltaQ_fthmc_2025)])

print("\n>>> deltaQ")
print(f"deltaQ ratio for HMC L32 b6: {np.mean(deltaQ_hmc)}")
print(f"deltaQ for FTHMC L32 b6: {np.mean(deltaQ_fthmc_1331)}, {np.mean(deltaQ_fthmc_1984)}, {np.mean(deltaQ_fthmc_1999)}, {np.mean(deltaQ_fthmc_2008)}, {np.mean(deltaQ_fthmc_2017)}, {np.mean(deltaQ_fthmc_2025)}")
print(f"mean(deltaQ) ratio for FTHMC L32 b6: {deltaQ_fthmc_L32_b6_mean / deltaQ_hmc_L32_b6_mean}")
print(f"std(deltaQ) ratio for FTHMC L32 b6: {deltaQ_fthmc_L32_b6_std / deltaQ_hmc_L32_b6_mean}")
# Out:
# >>> gamma ratio (16)
# gamma ratio (16) for L32 b6: 1.9801553062985349, 0.0, 2.295944779982746, 1.7791199309749786, 0.7368421052631593, 2.63589301121657
# mean(16) for L32 b6: 1.5713258556226648
# std(16) for L32 b6: 0.915980693570547
#
# >>> deltaQ
# deltaQ ratio for HMC L32 b6: 0.021001221001221003
# deltaQ for FTHMC L32 b6: 0.03540903540903541, 0.0, 0.03467643467643468, 0.02783882783882784, 0.01562881562881563, 0.04151404151404151
# mean(deltaQ) ratio for FTHMC L32 b6: 1.2306201550387597
# std(deltaQ) ratio for FTHMC L32 b6: 0.6709485933385287
# /tmp/ipykernel_199886/1709998247.py:4: RuntimeWarning: divide by zero encountered in scalar divide
#   gamma_fthmc_1984 = 1 / (1 - fthmc_res2attn_L32_b6_auto_1984[16])

# %% [markdown]
# ### L64 b6

# %%
hmc_L64_b6_topo = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/scaling/dumps/topo_hmc_L64_beta6.0_nsteps{n_steps}.csv')

fthmc_res2attn_L64_b6_topo_1331 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L64_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_1331.csv')
fthmc_res2attn_L64_b6_topo_1984 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L64_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_1984.csv')
fthmc_res2attn_L64_b6_topo_1999 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L64_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_1999.csv')
fthmc_res2attn_L64_b6_topo_2008 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L64_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_2008.csv')
fthmc_res2attn_L64_b6_topo_2017 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L64_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_2017.csv')
fthmc_res2attn_L64_b6_topo_2025 = np.loadtxt(f'/eagle/fthmc/run/Scaling_FT_HMC/res2attn_evaluation/dumps/topo_fthmc_L64_beta6.0_nsteps{n_steps}_res2attn_train_b3.0_L32_2025.csv')

max_lag = 64
beta = 6.0
volume = 64**2

hmc_L64_b6_auto = auto_from_chi(hmc_L64_b6_topo, max_lag=max_lag, beta=beta, volume=volume)

fthmc_res2attn_L64_b6_auto_1331 = auto_from_chi(fthmc_res2attn_L64_b6_topo_1331, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L64_b6_auto_1984 = auto_from_chi(fthmc_res2attn_L64_b6_topo_1984, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L64_b6_auto_1999 = auto_from_chi(fthmc_res2attn_L64_b6_topo_1999, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L64_b6_auto_2008 = auto_from_chi(fthmc_res2attn_L64_b6_topo_2008, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L64_b6_auto_2017 = auto_from_chi(fthmc_res2attn_L64_b6_topo_2017, max_lag=max_lag, beta=beta, volume=volume)
fthmc_res2attn_L64_b6_auto_2025 = auto_from_chi(fthmc_res2attn_L64_b6_topo_2025, max_lag=max_lag, beta=beta, volume=volume)


fig, ax = default_plot()
ax.scatter(np.arange(len(hmc_L64_b6_auto)), hmc_L64_b6_auto, label='HMC, $L=64$, $\\beta=6.0$', marker=marker_ls[0], color=color_ls[0])

ax.scatter(np.arange(len(fthmc_res2attn_L64_b6_auto_1331)), fthmc_res2attn_L64_b6_auto_1331, label='res2attn $L=32$, seed=$1331$', marker=marker_ls[1], color=color_ls[1])
ax.scatter(np.arange(len(fthmc_res2attn_L64_b6_auto_1984)), fthmc_res2attn_L64_b6_auto_1984, label='res2attn $L=32$, seed=$1984$', marker=marker_ls[2], color=color_ls[2])
ax.scatter(np.arange(len(fthmc_res2attn_L64_b6_auto_1999)), fthmc_res2attn_L64_b6_auto_1999, label='res2attn $L=32$, seed=$1999$', marker=marker_ls[3], color=color_ls[3])
ax.scatter(np.arange(len(fthmc_res2attn_L64_b6_auto_2008)), fthmc_res2attn_L64_b6_auto_2008, label='res2attn $L=32$, seed=$2008$', marker=marker_ls[4], color=color_ls[4])
ax.scatter(np.arange(len(fthmc_res2attn_L64_b6_auto_2017)), fthmc_res2attn_L64_b6_auto_2017, label='res2attn $L=32$, seed=$2017$', marker=marker_ls[5], color=color_ls[5])
ax.scatter(np.arange(len(fthmc_res2attn_L64_b6_auto_2025)), fthmc_res2attn_L64_b6_auto_2025, label='res2attn $L=32$, seed=$2025$', marker=marker_ls[6], color=color_ls[6])


ax.set_ylim(0.8, 1.02)
ax.legend(ncol=2, loc='upper right', fontsize=12)
ax.set_xlabel('MDTU', **fs_p)
ax.set_ylabel('Autocorrelation', **fs_p)
plt.tight_layout()
plt.savefig('plots/res2attn_train_b3_L32_autocorrelation_L64_b6.pdf', transparent=True)
plt.show()

# %%
idx = 16

gamma_hmc = 1 / (1 - hmc_L64_b6_auto[idx])

gamma_fthmc_1331 = 1 / (1 - fthmc_res2attn_L64_b6_auto_1331[idx])
gamma_fthmc_1984 = 1 / (1 - fthmc_res2attn_L64_b6_auto_1984[idx])
gamma_fthmc_1999 = 1 / (1 - fthmc_res2attn_L64_b6_auto_1999[idx])
gamma_fthmc_2008 = 1 / (1 - fthmc_res2attn_L64_b6_auto_2008[idx])
gamma_fthmc_2017 = 1 / (1 - fthmc_res2attn_L64_b6_auto_2017[idx])
gamma_fthmc_2025 = 1 / (1 - fthmc_res2attn_L64_b6_auto_2025[idx])

gamma_ratio_1331 = gamma_hmc / gamma_fthmc_1331
gamma_ratio_1984 = gamma_hmc / gamma_fthmc_1984
gamma_ratio_1999 = gamma_hmc / gamma_fthmc_1999
gamma_ratio_2008 = gamma_hmc / gamma_fthmc_2008
gamma_ratio_2017 = gamma_hmc / gamma_fthmc_2017
gamma_ratio_2025 = gamma_hmc / gamma_fthmc_2025

gamma_ratio_L64_b6_mean = np.mean([gamma_ratio_1331, gamma_ratio_1984, gamma_ratio_1999, gamma_ratio_2008, gamma_ratio_2017, gamma_ratio_2025])
gamma_ratio_L64_b6_std = np.std([gamma_ratio_1331, gamma_ratio_1984, gamma_ratio_1999, gamma_ratio_2008, gamma_ratio_2025])


print(f">>> gamma ratio ({idx})")
print(f"gamma ratio ({idx}) for L64 b6: {gamma_ratio_1331}, {gamma_ratio_1984}, {gamma_ratio_1999}, {gamma_ratio_2008}, {gamma_ratio_2017}, {gamma_ratio_2025}")
print(f"mean({idx}) for L64 b6: {gamma_ratio_L64_b6_mean}")
print(f"std({idx}) for L64 b6: {gamma_ratio_L64_b6_std}")

deltaQ_hmc = [ abs(hmc_L64_b6_topo[i] - hmc_L64_b6_topo[i-1]) for i in range(1, len(hmc_L64_b6_topo))]

deltaQ_fthmc_1331 = [ abs(fthmc_res2attn_L64_b6_topo_1331[i] - fthmc_res2attn_L64_b6_topo_1331[i-1]) for i in range(1, len(fthmc_res2attn_L64_b6_topo_1331))]
deltaQ_fthmc_1984 = [ abs(fthmc_res2attn_L64_b6_topo_1984[i] - fthmc_res2attn_L64_b6_topo_1984[i-1]) for i in range(1, len(fthmc_res2attn_L64_b6_topo_1984))]
deltaQ_fthmc_1999 = [ abs(fthmc_res2attn_L64_b6_topo_1999[i] - fthmc_res2attn_L64_b6_topo_1999[i-1]) for i in range(1, len(fthmc_res2attn_L64_b6_topo_1999))]
deltaQ_fthmc_2008 = [ abs(fthmc_res2attn_L64_b6_topo_2008[i] - fthmc_res2attn_L64_b6_topo_2008[i-1]) for i in range(1, len(fthmc_res2attn_L64_b6_topo_2008))]
deltaQ_fthmc_2017 = [ abs(fthmc_res2attn_L64_b6_topo_2017[i] - fthmc_res2attn_L64_b6_topo_2017[i-1]) for i in range(1, len(fthmc_res2attn_L64_b6_topo_2017))]
deltaQ_fthmc_2025 = [ abs(fthmc_res2attn_L64_b6_topo_2025[i] - fthmc_res2attn_L64_b6_topo_2025[i-1]) for i in range(1, len(fthmc_res2attn_L64_b6_topo_2025))]

deltaQ_hmc_L64_b6_mean = np.mean(deltaQ_hmc)
deltaQ_fthmc_L64_b6_mean = np.mean([np.mean(deltaQ_fthmc_1331), np.mean(deltaQ_fthmc_1984), np.mean(deltaQ_fthmc_1999), np.mean(deltaQ_fthmc_2008), np.mean(deltaQ_fthmc_2017), np.mean(deltaQ_fthmc_2025)])
deltaQ_fthmc_L64_b6_std = np.std([np.mean(deltaQ_fthmc_1331), np.mean(deltaQ_fthmc_1984), np.mean(deltaQ_fthmc_1999), np.mean(deltaQ_fthmc_2008), np.mean(deltaQ_fthmc_2017), np.mean(deltaQ_fthmc_2025)])

print("\n>>> deltaQ")
print(f"deltaQ for HMC L64 b6: {np.mean(deltaQ_hmc)}")
print(f"deltaQ for FTHMC L64 b6: {np.mean(deltaQ_fthmc_1331)}, {np.mean(deltaQ_fthmc_1984)}, {np.mean(deltaQ_fthmc_1999)}, {np.mean(deltaQ_fthmc_2008)}, {np.mean(deltaQ_fthmc_2017)}, {np.mean(deltaQ_fthmc_2025)}")
print(f"mean(deltaQ) ratio for FTHMC L64 b6: {deltaQ_fthmc_L64_b6_mean / deltaQ_hmc_L64_b6_mean}")
print(f"std(deltaQ) ratio for FTHMC L64 b6: {deltaQ_fthmc_L64_b6_std / deltaQ_hmc_L64_b6_mean}")
# Out:
# >>> gamma ratio (16)
# gamma ratio (16) for L64 b6: 0.1883304448295804, 0.23223570190641424, 0.0, 1.302426343154245, 0.5805892547660331, 2.4797804737146145
# mean(16) for L64 b6: 0.797227036395148
# std(16) for L64 b6: 0.93833546646458
#
# >>> deltaQ
# deltaQ for HMC L64 b6: 0.05518925518925519
# deltaQ for FTHMC L64 b6: 0.017094017094017096, 0.019291819291819293, 0.0, 0.0796092796092796, 0.03638583638583639, 0.1199023199023199
# mean(deltaQ) ratio for FTHMC L64 b6: 0.8222713864306787
# std(deltaQ) ratio for FTHMC L64 b6: 0.7524180556365411
# /tmp/ipykernel_199886/21068409.py:7: RuntimeWarning: divide by zero encountered in scalar divide
#   gamma_fthmc_1999 = 1 / (1 - fthmc_res2attn_L64_b6_auto_1999[idx])
